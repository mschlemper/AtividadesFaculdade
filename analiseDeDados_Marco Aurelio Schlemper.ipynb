# %% [markdown]
# <a href="https://colab.research.google.com/github/mschlemper/AtividadesFaculdade/blob/main/analiseDeDados_Marco%20Aurelio%20Schlemper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://calmcode.io/static/data/titanic.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    survived  pclass                                               name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       sex   age     fare  sibsp  parch
# 0    male  22.0   7.2500      1      0
# 1  female  38.0  71.2833      1      0
# 2  female  26.0   7.9250      0      0
# 3  female  35.0  53.1000      1      0
# 4    male  35.0   8.0500      0      0

# %%
# Criar o conteúdo do README.md
readme_content = """
# Projeto de Análise Exploratória de Dados – Titanic

## 📌 Introdução
Este projeto foi desenvolvido como atividade prática extra do curso **Introdução ao Data Science (IP 20h A)**. O objetivo é aplicar conceitos fundamentais de Data Science por meio da análise exploratória de dados (AED), utilizando a base pública do Titanic. A análise busca compreender padrões, relações entre variáveis e fatores associados à sobrevivência dos passageiros.

## ⚙️ Etapas Realizadas
1. Importação dos dados: o dataset Titanic foi carregado em formato CSV diretamente no Google Colab.
2. Exploração inicial: foram verificadas as colunas, tipos de dados e valores nulos.
3. Tratamento dos dados:
   - Valores nulos em Age foram preenchidos com a mediana.
   - Valores nulos em Embarked foram preenchidos com o valor mais frequente.
   - Registros duplicados foram removidos.
   - Colunas categóricas foram convertidas para o tipo category.
4. Estatísticas descritivas: foram calculadas médias, distribuições e proporções de sobrevivência.
5. Agrupamentos e comparações: análise da taxa de sobrevivência por sexo e por classe.
6. Visualizações gráficas: histogramas e gráficos de barras foram gerados para ilustrar distribuições e relações entre variáveis.

## 📊 Principais Insights
- A taxa de sobrevivência foi maior entre mulheres em comparação aos homens.
- Passageiros da 1ª classe tiveram maior chance de sobrevivência do que os da 2ª e 3ª classes.
- A distribuição de idades mostra que havia muitos jovens a bordo, e a idade influenciou parcialmente na sobrevivência.
- O fator socioeconômico (classe) e o gênero foram determinantes para a sobrevivência.

## 🛠️ Ferramentas Utilizadas
- Python
- Pandas para manipulação de dados
- Seaborn e Matplotlib para visualizações gráficas
- Google Colab como ambiente de desenvolvimento

## 📂 Estrutura do Projeto
- titanic.csv → dataset utilizado
- notebook.ipynb → código fonte em Python
- README.md → documentação do projeto

## ✅ Conclusão
Este projeto permitiu consolidar conceitos de Data Science, como importação, limpeza, análise e visualização de dados. A análise exploratória revelou padrões importantes sobre os fatores que influenciaram a sobrevivência dos passageiros do Titanic, demonstrando a relevância da ciência de dados para compreender fenômenos complexos e apoiar decisões baseadas em evidências.
"""

# Salvar o README.md
with open("README.md", "w", encoding="utf-8") as f:
    f.write(readme_content)

print("README.md gerado com sucesso!")
# Out:
# README.md gerado com sucesso!

# %%
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 714 entries, 0 to 713
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  714 non-null    int64
#  1   pclass    714 non-null    int64
#  2   name      714 non-null    object
#  3   sex       714 non-null    object
#  4   age       714 non-null    float64
#  5   fare      714 non-null    float64
#  6   sibsp     714 non-null    int64
#  7   parch     714 non-null    int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 44.8+ KB
# survived    0
# pclass      0
# name        0
# sex         0
# age         0
# fare        0
# sibsp       0
# parch       0
# dtype: int64

# %%
df['age'] = df['age'].fillna(df['age'].median())
df.drop_duplicates(inplace=True)

# %%
# Taxa de sobrevivência por sexo
print(df.groupby('sex')['survived'].mean())

# Taxa de sobrevivência por classe
print(df.groupby('pclass')['survived'].mean())
# Out:
# sex
# female    0.754789
# male      0.205298
# Name: survived, dtype: float64
# pclass
# 1    0.655914
# 2    0.479769
# 3    0.239437
# Name: survived, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['age'], bins=30, kde=True)
plt.title("Distribuição de Idade")
plt.show()

sns.barplot(x='sex', y='survived', data=df)
plt.title("Taxa de Sobrevivência por Sexo")
plt.show()

sns.barplot(x='pclass', y='survived', data=df)
plt.title("Taxa de Sobrevivência por Classe")
plt.show()

# %%
# Criar o conteúdo do README.md
readme_content = """
# Projeto de Análise Exploratória de Dados – Titanic

## 📌 Introdução
Este projeto foi desenvolvido como atividade prática extra do curso **Introdução ao Data Science (IP 20h A)**. O objetivo é aplicar conceitos fundamentais de Data Science por meio da análise exploratória de dados (AED), utilizando a base pública do Titanic. A análise busca compreender padrões, relações entre variáveis e fatores associados à sobrevivência dos passageiros.

## ⚙️ Etapas Realizadas
1. Importação dos dados: o dataset Titanic foi carregado em formato CSV diretamente no Google Colab.
2. Exploração inicial: foram verificadas as colunas, tipos de dados e valores nulos.
3. Tratamento dos dados:
   - Valores nulos em Age foram preenchidos com a mediana.
   - Valores nulos em Embarked foram preenchidos com o valor mais frequente.
   - Registros duplicados foram removidos.
   - Colunas categóricas foram convertidas para o tipo category.
4. Estatísticas descritivas: foram calculadas médias, distribuições e proporções de sobrevivência.
5. Agrupamentos e comparações: análise da taxa de sobrevivência por sexo e por classe.
6. Visualizações gráficas: histogramas e gráficos de barras foram gerados para ilustrar distribuições e relações entre variáveis.

## 📊 Principais Insights
- A taxa de sobrevivência foi maior entre mulheres em comparação aos homens.
- Passageiros da 1ª classe tiveram maior chance de sobrevivência do que os da 2ª e 3ª classes.
- A distribuição de idades mostra que havia muitos jovens a bordo, e a idade influenciou parcialmente na sobrevivência.
- O fator socioeconômico (classe) e o gênero foram determinantes para a sobrevivência.

## 🛠️ Ferramentas Utilizadas
- Python
- Pandas para manipulação de dados
- Seaborn e Matplotlib para visualizações gráficas
- Google Colab como ambiente de desenvolvimento

## 📂 Estrutura do Projeto
- titanic.csv → dataset utilizado
- notebook.ipynb → código fonte em Python
- README.md → documentação do projeto

## ✅ Conclusão
Este projeto permitiu consolidar conceitos de Data Science, como importação, limpeza, análise e visualização de dados. A análise exploratória revelou padrões importantes sobre os fatores que influenciaram a sobrevivência dos passageiros do Titanic, demonstrando a relevância da ciência de dados para compreender fenômenos complexos e apoiar decisões baseadas em evidências.
"""

# Salvar o README.md
with open("README.md", "w", encoding="utf-8") as f:
    f.write(readme_content)

print("README.md gerado com sucesso!")
# Out:
# README.md gerado com sucesso!
